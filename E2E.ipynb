# %% [markdown]
# <a href="https://colab.research.google.com/github/izumatthew/HHA504_E2E/blob/main/E2E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
# !pip install pymysql
# Out:
# ...
#      |████████████████████████████████| 43 kB 1.5 MB/s
# ...

# %%
from sqlalchemy import create_engine

# %%
MYSQL_HOSTNAME = '52.188.215.210' # change this to your IP address which is found on your AZURE dashboard 
MYSQL_USER = 'dba'
MYSQL_PASSWORD = 'ahi2021'
MYSQL_DATABASE = 'AHIServer'

connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
csvfile = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/AHI_STATS_507/main/Week_8_ANOVAS/DataSet/diabetic_data.csv')

# %%
csvfile.to_sql('diabetic_data', con=engine, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-9ad4e6392be8> in <module>()
# ----> 1 csvfile.to_sql('diabetic_data', con=engine, if_exists='append')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ...
